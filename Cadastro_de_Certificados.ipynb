# %% [markdown]
# <a href="https://colab.research.google.com/github/86HenriqueSilva/Organizar_Certificados/blob/main/Cadastro_de_Certificados.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
#  **Edson Henrique**
#
#
#  Análise e Desenvolvimento de Sistemas - UNINABUCO
#
# Links:
#
# [Linkedin](https://linkedin.com/in/henriquesilvatech) | [GitHub](https://github.com/86HenriqueSilva) | [Perfil na DIO](https://dio.me/users/edson_henrique)
#
# Descrição: Profissional em constante aprimoramento técnico e acadêmico na área de Tecnologia da Informação e Desenvolvimento de Sistemas. Experiência consolidada em diversas tecnologias e metodologias, incluindo Python, Java, AWS, Docker, e Análise de Dados. Capacitado em liderança, gestão de projetos e implementações de soluções complexas em ambientes de TI.
#
# Busco continuamente integrar novos conhecimentos e habilidades para enfrentar desafios emergentes no mercado digital e de nuvem.
#
# Detalhes adicionais:
#
#        Habilidades e Interesses:
#
#     Proficiência em linguagens como Python, Java e Kotlin para desenvolvimento backend e análise de dados.
#     Interesse crescente em inteligência artificial, machine learning e suas aplicações práticas.
#     Familiaridade com metodologias ágeis, DevOps e práticas de desenvolvimento moderno.

# %% [markdown]
# # **Cadastro de Certificados**

# %% [markdown]
# # Resumo do Código:
#
#     Importações de Bibliotecas:
#         pandas: Para manipulação de dados em formato tabular.
#         os: Para operações com sistema operacional, como verificar a existência de arquivos e criar diretórios.
#         uuid: Para geração de IDs únicos para cada certificado adicionado.
#         datetime: Para validar e manipular datas.
#         tabulate: Para formatar a exibição dos dados em formato de tabela.
#
#     Montagem do Google Drive:
#         Utiliza o módulo drive do Google Colab para montar o Google Drive onde será salvo o arquivo CSV dos certificados.
#
#     Dados Pessoais e Caminho do Arquivo:
#         Define o nome do usuário (nome).
#         Define o caminho onde será salvo o arquivo CSV (drive_path).
#         Caso o diretório não exista, ele é criado.
#         Define o caminho completo do arquivo CSV (path).
#
#     Verificação e Carregamento do Arquivo CSV:
#         Verifica se o arquivo CSV já existe no caminho especificado.
#         Se existir, carrega o DataFrame (df_certificados) a partir desse arquivo.
#         > Caso não exista, cria um novo DataFrame vazio com as colunas padrão:
#         "ID", "Nome", "Curso", "Data", "Carga Horária", "Instituição", "Link".
#
#     Funções Definidas:
#         Validar_data(data): Função para validar se a data está no formato correto (AAAA-MM-DD).
#
#         adicionar_certificado(nome, curso, data, carga_horaria, instituicao, link):
#         Adiciona um novo certificado ao DataFrame df_certificados,
#         gera um ID único para o certificado, ordena os certificados por data e salva o DataFrame atualizado no arquivo CSV.
#
#         visualizar_certificados():
#          Exibe todos os certificados existentes no DataFrame formatados como uma tabela usando o tabulate.
#
#         Mostrar_menu():
#         Implementa um menu interativo onde o usuário pode escolher entre adicionar um novo certificado,
#         visualizar todos os certificados ou sair do programa.
#
#     Execução do Menu Interativo:
#         Dentro da função mostrar_menu(), um loop contínuo permite que o usuário escolha diferentes opções de interação com o programa:
#             Opção "1": Adiciona um novo certificado solicitando informações como nome do curso, data, carga horária, instituição e link.
#             Opção "2": Exibe todos os certificados existentes no formato de tabela.
#             Opção "3": Encerra o programa.

# %% [markdown]
# # Objetivo do Código:
#
# O código tem como objetivo principal fornecer uma interface interativa para adicionar, visualizar e gerenciar certificados de cursos, armazenando esses dados em um arquivo CSV no Google Drive. Ele oferece funcionalidades básicas de entrada de dados, validação de entrada e visualização organizada dos certificados.
# Tecnologias Utilizadas:
#
#     Python: Linguagem principal para desenvolvimento.
#     Pandas: Para manipulação e armazenamento de dados estruturados.
#     Google Colab: Ambiente utilizado para execução do código com integração ao Google Drive.
#     Tabulate: Para formatação e exibição de dados em formato de tabela.
#
# Esse resumo abrange os principais aspectos do código, destacando seu propósito, funcionalidades e as tecnologias envolvidas.

# %%
import pandas as pd
import os
import uuid
from datetime import datetime
from tabulate import tabulate  # Importar tabulate para formatar a tabela

# Montar o Google Drive
from google.colab import drive
drive.mount('/content/drive')

# Dados pessoais
nome = "E.H.F.S"

# Caminho para salvar o arquivo CSV no Google Drive
drive_path = '/content/drive/MyDrive/Certificados'
if not os.path.exists(drive_path):
    os.makedirs(drive_path)
path = os.path.join(drive_path, 'certificados.csv')

# Verifica se o arquivo já existe
if os.path.exists(path):
    df_certificados = pd.read_csv(path)
else:
    df_certificados = pd.DataFrame(columns=["ID", "Nome", "Curso", "Data", "Carga Horária", "Instituição", "Link"])

# Função para validar a data
def validar_data(data):
    try:
        datetime.strptime(data, "%Y-%m-%d")
        return True
    except ValueError:
        return False

# Função para adicionar um certificado
def adicionar_certificado(nome, curso, data, carga_horaria, instituicao, link):
    global df_certificados
    id_unico = str(uuid.uuid4())
    novo_certificado = pd.DataFrame({
        "ID": [id_unico],
        "Nome": [nome.upper()],
        "Curso": [curso.upper()],
        "Data": [data],
        "Carga Horária": [int(carga_horaria)],
        "Instituição": [instituicao.upper()],
        "Link": [link]
    })
    df_certificados = pd.concat([df_certificados, novo_certificado], ignore_index=True)
    df_certificados.sort_values(by="Data", inplace=True)
    df_certificados.to_csv(path, index=False)
    print(f"Certificado do curso '{curso}' adicionado com sucesso!")

# Função para visualizar todos os certificados
def visualizar_certificados():
    global df_certificados
    if df_certificados.empty:
        print("Nenhum certificado encontrado.")
    else:
        # Formatar os dados em uma tabela usando tabulate
        print(tabulate(df_certificados, headers='keys', tablefmt='fancy_grid'))

# Função para mostrar o menu
def mostrar_menu():
    while True:
        print("\nMenu de Opções")
        print("1. Adicionar Certificado")
        print("2. Visualizar Todos os Certificados")
        print("3. Sair")
        opcao = input("Escolha uma opção: ")

        if opcao == "1":
            curso = input("Digite o nome do curso: ").strip()
            data = input("Digite a data de conclusão (AAAA-MM-DD): ").strip()
            while not validar_data(data):
                print("Data inválida. Por favor, insira no formato AAAA-MM-DD.")
                data = input("Digite a data de conclusão (AAAA-MM-DD): ").strip()
            carga_horaria = input("Digite a carga horária: ").strip()
            while not carga_horaria.isdigit() or int(carga_horaria) <= 0:
                print("Carga horária inválida. Por favor, insira um número positivo.")
                carga_horaria = input("Digite a carga horária: ").strip()
            instituicao = input("Digite o nome da instituição: ").strip()
            link = input("Digite o link de acesso em nuvem: ").strip()
            adicionar_certificado(nome, curso, data, carga_horaria, instituicao, link)
        elif opcao == "2":
            visualizar_certificados()
        elif opcao == "3":
            print("Saindo...")
            break
        else:
            print("Opção inválida. Tente novamente.")

# Mostrar o menu
mostrar_menu()
# Out:
# Mounted at /content/drive
#
# Menu de Opções
# 1. Adicionar Certificado
# 2. Visualizar Todos os Certificados
# 3. Sair
# Escolha uma opção: 2
# ╒═════╤══════════════════════════════════════╤═════════╤═══════════════════════════════════════════════════════════════════════════════════════════════════╤════════════╤═════════════════╤═════════════════════════╤════════════════════════════════════════════════════════════════════════════════════╕
# │     │ ID                                   │ Nome    │ Curso                                                                                             │ Data       │   Carga Horária │ Instituição             │ Link                                                                               │
# ╞═════╪══════════════════════════════════════╪═════════╪═══════════════════════════════════════════════════════════════════════════════════════════════════╪════════════╪═════════════════╪═════════════════════════╪════════════════════════════════════════════════════════════════════════════════════╡
# │   0 │ d5190ff1-9827-4f90-9e98-38313d247014 │ E.H.F.S │ ELÊTRICA PARA COMPUTADORES                                                                        │ 2007-04-30 │             171 │ ECPIE-LEIAUT            │ https://drive.google.com/file/d/12fwDDoUfcB9nF55bm8_XVDpTpluwqBgB/view?usp=sharing │
# ├─────┼──────────────────────────────────────┼─────────┼───────────────────────────────────────────────────────────────────────────────────────────────────┼────────────┼─────────────────┼─────────────────────────┼────────────────────────────────────────────────────────────────────────────────────┤
# │   1 │ 779481a2-06b8-444e-a0aa-6b3a86b71e2b │ E.H.F.S │ TÉCNICO EM INFORMÁTICA                                                                            │ 2009-02-27 │            1130 │ ECPIE-LEIAUT            │ https://drive.google.com/file/d/1wrevqWp7wDPFYhNxbIkz3ei9P_aQzQ6_/view?usp=sharing │
# ├─────┼──────────────────────────────────────┼─────────┼───────────────────────────────────────────────────────────────────────────────────────────────────┼────────────┼─────────────────┼─────────────────────────┼────────────────────────────────────────────────────────────────────────────────────┤
# │   2 │ 96a1d50c-3b99-4c41-b810-1c5cf7b27a50 │ E.H.F.S │ ELETRÔNICA ANALÓGICA (REPARO) ESTABILIZADOR | NOBREAK| CIRCUITOS ELETRÔNICOS | MICROPROCESSADORES │ 2009-04-08 │              78 │ ECPIE-LEIAUT            │ https://drive.google.com/file/d/1hxNZJfpQsqkQtG1Y7upGbp0FOIXZpjnn/view?usp=sharing │
# ├─────┼──────────────────────────────────────┼─────────┼───────────────────────────────────────────────────────────────────────────────────────────────────┼────────────┼─────────────────┼─────────────────────────┼────────────────────────────────────────────────────────────────────────────────────┤
# │   3 │ 02e959d7-13c8-4014-b37f-bc7764078840 │ E.H.F.S │ LOGISTICA PARA FATURAMENTO DE CONVÊNIOS TISS | TUSS | CBHPM                                       │ 2010-10-16 │               8 │ IOR                     │ https://drive.google.com/file/d/1RmaYMxUIl7Wh1i_ZN7KvqtxNcTbVkQQc/view?usp=sharing │
# ├─────┼──────────────────────────────────────┼─────────┼───────────────────────────────────────────────────────────────────────────────────────────────────┼────────────┼─────────────────┼─────────────────────────┼────────────────────────────────────────────────────────────────────────────────────┤
# │   4 │ d9122e76-1c80-4a99-b4b1-99f8f230e794 │ E.H.F.S │ GESTÃO EM FATURAMENTO E AUDITÓRIA DE CONVÊNIOS MÉDICOS                                            │ 2012-11-22 │              16 │ IOR                     │ https://drive.google.com/file/d/1zPYkKMgekgeTcdKnqRq2IrD05scNuwkG/view?usp=sharing │
# ├─────┼──────────────────────────────────────┼─────────┼───────────────────────────────────────────────────────────────────────────────────────────────────┼────────────┼─────────────────┼─────────────────────────┼────────────────────────────────────────────────────────────────────────────────────┤
# │   5 │ d562c69c-81e4-4bd2-9946-6177a27a7a9a │ E.H.F.S │ EXCEL 2010                                                                                        │ 2013-11-18 │              12 │ INTERDATA               │ https://drive.google.com/file/d/119qt8CGD3GOtxs6shL21tQwkUCN7tF17/view?usp=sharing │
# ├─────┼──────────────────────────────────────┼─────────┼───────────────────────────────────────────────────────────────────────────────────────────────────┼────────────┼─────────────────┼─────────────────────────┼────────────────────────────────────────────────────────────────────────────────────┤
# │   6 │ c8f97b25-6c35-4b18-a2d0-dea7383010a1 │ E.H.F.S │ EXCEL 2010                                                                                        │ 2013-11-18 │              12 │ INTERDATA               │ https://drive.google.com/file/d/1dQkl2-th9NuPuYqHWit7zP2eTTabnRez/view?usp=sharing │
# ├─────┼──────────────────────────────────────┼─────────┼───────────────────────────────────────────────────────────────────────────────────────────────────┼────────────┼─────────────────┼─────────────────────────┼────────────────────────────────────────────────────────────────────────────────────┤
# │   7 │ ec111055-0ed3-4d32-bedc-3ae2d848646c │ E.H.F.S │ EXCEL 2010 BÁSICO                                                                                 │ 2014-07-02 │              24 │ FUNDAÇÃO BRADESCO       │ https://drive.google.com/file/d/1arITc3-8hJU97b0GjVa2kfyJ7F-iWw_1/view?usp=sharing │
# ├─────┼──────────────────────────────────────┼─────────┼───────────────────────────────────────────────────────────────────────────────────────────────────┼────────────┼─────────────────┼─────────────────────────┼────────────────────────────────────────────────────────────────────────────────────┤
# │   8 │ cc231461-6389-470e-b28c-7a623710e1e1 │ E.H.F.S │ EXCEL 2010 INTERMEDIÁRIO                                                                          │ 2014-07-02 │              10 │ FUNDAÇÃO BRADESCO       │ https://drive.google.com/file/d/12CR8lyJ37v1MlX3kt7t3J1yIQVaP_up5/view?usp=sharing │
# ├─────┼──────────────────────────────────────┼─────────┼───────────────────────────────────────────────────────────────────────────────────────────────────┼────────────┼─────────────────┼─────────────────────────┼────────────────────────────────────────────────────────────────────────────────────┤
# │   9 │ b94ff068-c869-449e-9c35-ae52594d8ac3 │ E.H.F.S │ EXCEL 2010                                                                                        │ 2014-07-02 │              20 │ FUNDAÇÃO BRADESCO       │ https://drive.google.com/file/d/1MTADK-U92528czXym0KagBPiqJlghHFG/view?usp=sharing │
# ├─────┼──────────────────────────────────────┼─────────┼───────────────────────────────────────────────────────────────────────────────────────────────────┼────────────┼─────────────────┼─────────────────────────┼────────────────────────────────────────────────────────────────────────────────────┤
# │  10 │ 554b7cbf-b7fd-46dc-bbd1-c2c836ddf48b │ E.H.F.S │ IMPLANTAÇÃO DE SISTEMA PFSENSE (FIREWALL)                                                         │ 2015-05-01 │              24 │ PONTO FORTE             │ https://drive.google.com/file/d/1Itn07FhPkoB_94igVxRzb9ZLDXqyOQ4J/view?usp=sharing │
# ├─────┼──────────────────────────────────────┼─────────┼───────────────────────────────────────────────────────────────────────────────────────────────────┼────────────┼─────────────────┼─────────────────────────┼────────────────────────────────────────────────────────────────────────────────────┤
# │  11 │ 674b4916-785b-4571-a0e3-4b8ca70329e4 │ E.H.F.S │ ADMINISTRANDO SEU DINHEIRO                                                                        │ 2016-08-03 │              12 │ SESI                    │ https://drive.google.com/file/d/1llGvEP2__hBOlT51Q7jzOLpXhRHI786g/view?usp=sharing │
# ├─────┼──────────────────────────────────────┼─────────┼───────────────────────────────────────────────────────────────────────────────────────────────────┼────────────┼─────────────────┼─────────────────────────┼────────────────────────────────────────────────────────────────────────────────────┤
# │  12 │ ba2f549d-58c8-4eec-8922-951e7abea78a │ E.H.F.S │ EMPRESÁRIO DO TERCEIRO MILÊNIO                                                                    │ 2016-08-15 │              12 │ SESI                    │ https://drive.google.com/file/d/1QM7cG4EvVB5gRk6Hr0yeGB8D3GXdOHiE/view?usp=sharing │
# ├─────┼──────────────────────────────────────┼─────────┼───────────────────────────────────────────────────────────────────────────────────────────────────┼────────────┼─────────────────┼─────────────────────────┼────────────────────────────────────────────────────────────────────────────────────┤
# │  13 │ b38a2d82-a670-48aa-a215-111fc0aef36a │ E.H.F.S │ LIDERANÇA: LIDER X CHEFE                                                                          │ 2016-09-01 │              12 │ SESI                    │ https://drive.google.com/file/d/1hBrN-od3jwPI8y4reypHeXObTlTsc7T7/view?usp=sharing │
# ├─────┼──────────────────────────────────────┼─────────┼───────────────────────────────────────────────────────────────────────────────────────────────────┼────────────┼─────────────────┼─────────────────────────┼────────────────────────────────────────────────────────────────────────────────────┤
# │  14 │ 716728e0-47a8-4216-9188-742447f48dad │ E.H.F.S │ CURSO DE SATISFAÇÃO DO CLIENTE                                                                    │ 2016-09-01 │              40 │ SESI                    │ https://drive.google.com/file/d/1kOnNLZ-Xsb0U0ayE3gIw2abm-8coOF4B/view?usp=sharing │
# ├─────┼──────────────────────────────────────┼─────────┼───────────────────────────────────────────────────────────────────────────────────────────────────┼────────────┼─────────────────┼─────────────────────────┼────────────────────────────────────────────────────────────────────────────────────┤
# │  15 │ 728a6dca-396e-4923-877e-e2d82158060f │ E.H.F.S │ LIDERANÇA : LIDER X CHEFE                                                                         │ 2016-09-01 │              12 │ SESI                    │ https://drive.google.com/file/d/1yEsPPCUyeWtFwDVv4GRveTE6BzHU5XVB/view?usp=sharing │
# ├─────┼──────────────────────────────────────┼─────────┼───────────────────────────────────────────────────────────────────────────────────────────────────┼────────────┼─────────────────┼─────────────────────────┼────────────────────────────────────────────────────────────────────────────────────┤
# │  16 │ 750c5d9d-dd4d-4fdd-a6c8-98b3487fbc52 │ E.H.F.S │ CFTV                                                                                              │ 2020-07-13 │               4 │ ITEC                    │ https://drive.google.com/file/d/18EQLI8Idv7OrTUU2ia6SalJ_eqGt8JdA/view?usp=sharing │
# ├─────┼──────────────────────────────────────┼─────────┼───────────────────────────────────────────────────────────────────────────────────────────────────┼────────────┼─────────────────┼─────────────────────────┼────────────────────────────────────────────────────────────────────────────────────┤
# │  17 │ 410a0a18-389c-4274-9945-607fba5022f1 │ E.H.F.S │ ALGORITMO                                                                                         │ 2022-04-29 │              40 │ CURSO EM VIDEO          │ https://drive.google.com/file/d/1yOY4vPdnbMlVE41EVdUoYk7SfeI-Gwm4/view?usp=sharing │
# ├─────┼──────────────────────────────────────┼─────────┼───────────────────────────────────────────────────────────────────────────────────────────────────┼────────────┼─────────────────┼─────────────────────────┼────────────────────────────────────────────────────────────────────────────────────┤
# │  18 │ edfe215c-69c5-420b-a069-b8af3528963f │ E.H.F.S │ O MUNDO DO TRABALHO 4.0 E O MERCADO DIGITAL                                                       │ 2022-05-08 │               4 │ SOFTEX                  │ https://drive.google.com/file/d/1GCuc9aX_3LVvRmLFLwuHFnUwQkd5h8A8/view?usp=sharing │
# ├─────┼──────────────────────────────────────┼─────────┼───────────────────────────────────────────────────────────────────────────────────────────────────┼────────────┼─────────────────┼─────────────────────────┼────────────────────────────────────────────────────────────────────────────────────┤
# │  19 │ 38625fcd-952f-4f07-b370-4eeb72b3ad13 │ E.H.F.S │ LINGUAGEM PYTHON: APRENDENDO A LINGUAGEM (PARTE 1)                                                │ 2022-06-02 │               3 │ OCEAN                   │ https://drive.google.com/file/d/1INATy8MdxaW4H7bNxqHFI1U6NKC67_-C/view?usp=sharing │
# ├─────┼──────────────────────────────────────┼─────────┼───────────────────────────────────────────────────────────────────────────────────────────────────┼────────────┼─────────────────┼─────────────────────────┼────────────────────────────────────────────────────────────────────────────────────┤
# │  20 │ b5369e59-a15e-4bf6-a034-6521dbaef9e4 │ E.H.F.S │ LINGUAGEM PYTHON: APRENDENDO A LINGUAGEM (PARTE 3)                                                │ 2022-06-09 │               3 │ OCEAN                   │ https://drive.google.com/file/d/1EklKcBeFOz_QJftlGorFO9YpSapTgiT8/view?usp=sharing │
# ├─────┼──────────────────────────────────────┼─────────┼───────────────────────────────────────────────────────────────────────────────────────────────────┼────────────┼─────────────────┼─────────────────────────┼────────────────────────────────────────────────────────────────────────────────────┤
# │  21 │ 78a9e99d-5b8e-42f9-ac65-354cdc1066bd │ E.H.F.S │ CONSULTANDO BASES SQL COM PYTHON (PARTE 1)                                                        │ 2022-06-15 │               3 │ OCEAN                   │ https://drive.google.com/file/d/10Z9fT_pJgsomNYXtMEm2OmKQBovoW31Q/view?usp=sharing │
# ├─────┼──────────────────────────────────────┼─────────┼───────────────────────────────────────────────────────────────────────────────────────────────────┼────────────┼─────────────────┼─────────────────────────┼────────────────────────────────────────────────────────────────────────────────────┤
# │  22 │ a9be833a-f39b-4565-8b00-031833b8a151 │ E.H.F.S │ CIÊNCIA DE DADOS: VISUALIZAÇÃO DE DADOS COM PYTHON (PARTE 1)                                      │ 2022-06-15 │               3 │ OCEAN                   │ https://drive.google.com/file/d/19LRzigAx8kIrnCCVOwIlLvTXyo_65X8p/view?usp=sharing │
# ├─────┼──────────────────────────────────────┼─────────┼───────────────────────────────────────────────────────────────────────────────────────────────────┼────────────┼─────────────────┼─────────────────────────┼────────────────────────────────────────────────────────────────────────────────────┤
# │  23 │ 2881b787-1e2d-4fcf-a56b-95fafd9a2dc1 │ E.H.F.S │ CIÊNCIA DE DADOS: VISUALIZAÇÃO DE DADOS COM PYTHON (PARTE 2)                                      │ 2022-06-17 │               3 │ OCEAN                   │ https://drive.google.com/file/d/17wW0ZooBlgUEjuwCNN0FSim5UmOI7zyE/view?usp=sharing │
# ├─────┼──────────────────────────────────────┼─────────┼───────────────────────────────────────────────────────────────────────────────────────────────────┼────────────┼─────────────────┼─────────────────────────┼────────────────────────────────────────────────────────────────────────────────────┤
# │  24 │ 5e0da2d1-b55d-4fd8-a08c-08611dbd11da │ E.H.F.S │ CONSTRUINDO UMA APLICAÇÃO WEB COMPLETA COM PYTHON (PARTE 2)                                       │ 2022-07-25 │               3 │ OCEAN                   │ https://drive.google.com/file/d/1uvneYpnXgL4jOkcDdocMZLNYM79XLz72/view?usp=sharing │
# ├─────┼──────────────────────────────────────┼─────────┼───────────────────────────────────────────────────────────────────────────────────────────────────┼────────────┼─────────────────┼─────────────────────────┼────────────────────────────────────────────────────────────────────────────────────┤
# │  25 │ aa27db9b-cc75-4296-abab-9d1484e89bb2 │ E.H.F.S │ INTRODUÇÃO À INTERNET DAS COISAS                                                                  │ 2022-08-01 │               3 │ OCEAN                   │ https://drive.google.com/file/d/1hUG3oA_YJjZl5WxtY2ZaLItEOV8SgZQC/view?usp=sharing │
# ├─────┼──────────────────────────────────────┼─────────┼───────────────────────────────────────────────────────────────────────────────────────────────────┼────────────┼─────────────────┼─────────────────────────┼────────────────────────────────────────────────────────────────────────────────────┤
# │  26 │ ad8e483d-9ff5-43cb-986a-f7e5cd9edf68 │ E.H.F.S │ GIT E GITHUB COMO USAR SEM CÓDIGOS                                                                │ 2022-08-02 │               3 │ UNINABUCO               │ https://drive.google.com/file/d/13HEBypB9uHLERAl03bxQVp677DDOggXV/view?usp=sharing │
# ├─────┼──────────────────────────────────────┼─────────┼───────────────────────────────────────────────────────────────────────────────────────────────────┼────────────┼─────────────────┼─────────────────────────┼────────────────────────────────────────────────────────────────────────────────────┤
# │  27 │ 7236de6c-7f96-460f-a3df-d688d141e7ff │ E.H.F.S │ CLOUD COMPUTING: CONCEITOS E TERMINOLOGIAS                                                        │ 2022-08-04 │               3 │ FIAP                    │ https://drive.google.com/file/d/1PuuIY3SaYUF9yN9MFGkF8CqWCe2CPfJK/view?usp=sharing │
# ├─────┼──────────────────────────────────────┼─────────┼───────────────────────────────────────────────────────────────────────────────────────────────────┼────────────┼─────────────────┼─────────────────────────┼────────────────────────────────────────────────────────────────────────────────────┤
# │  28 │ 0f711933-e783-4ae4-a72e-00f0c995dd6e │ E.H.F.S │ CAPACITAÇÃO DO CURSO DE QUALIFICAÇÃO SOCIOPROFISSIONAL EM PROGRAMAÇÃO DE SOFTWARE – JAVA          │ 2022-08-05 │             440 │ SETEQ                   │ https://drive.google.com/file/d/1oqIWDgwHCqktT8RTUpGrud7evlg-VVQn/view?usp=sharing │
# ├─────┼──────────────────────────────────────┼─────────┼───────────────────────────────────────────────────────────────────────────────────────────────────┼────────────┼─────────────────┼─────────────────────────┼────────────────────────────────────────────────────────────────────────────────────┤
# │  29 │ fe0216bc-b354-4070-b63b-1fb2f34fc8d8 │ E.H.F.S │ INOVAÇÃO E BIOECONOMIA                                                                            │ 2022-08-12 │               4 │ OCEAN                   │ https://drive.google.com/file/d/1F5LyM-xpSdYWr8Av0vK0DLKAr_cSZ5zI/view?usp=sharing │
# ├─────┼──────────────────────────────────────┼─────────┼───────────────────────────────────────────────────────────────────────────────────────────────────┼────────────┼─────────────────┼─────────────────────────┼────────────────────────────────────────────────────────────────────────────────────┤
# │  30 │ 9bf774b5-e89c-4ba2-a1fb-dbc94e5fd168 │ E.H.F.S │ EMPREENDEDORISMO NA ERA DIGITAL                                                                   │ 2022-08-16 │               1 │ UNINABUCO               │ https://drive.google.com/file/d/1mWkG24unJ5P-FK_ZTiu3mlDH8Jl0D5yY/view?usp=sharing │
# ├─────┼──────────────────────────────────────┼─────────┼───────────────────────────────────────────────────────────────────────────────────────────────────┼────────────┼─────────────────┼─────────────────────────┼────────────────────────────────────────────────────────────────────────────────────┤
# │  31 │ b0b494dc-9fcf-45ff-bf9c-a534c33c783d │ E.H.F.S │ DESENVOLVIMENTO ÁGIL - DEVOPS GIT                                                                 │ 2022-08-22 │               3 │ OCEAN                   │ https://drive.google.com/file/d/1HVfLBeS1ylahACJId1SZRjsXhUbp4y5W/view?usp=sharing │
# ├─────┼──────────────────────────────────────┼─────────┼───────────────────────────────────────────────────────────────────────────────────────────────────┼────────────┼─────────────────┼─────────────────────────┼────────────────────────────────────────────────────────────────────────────────────┤
# │  32 │ ab15c76a-b6e7-4335-979b-c0fb4e65bc91 │ E.H.F.S │ METAVERSO: VERDADES E MITOS                                                                       │ 2022-09-08 │               3 │ UNINABUCO               │ https://drive.google.com/file/d/1PBU94RE6_jzxugPyYI5V1JeuD9s64YDx/view?usp=sharing │
# ├─────┼──────────────────────────────────────┼─────────┼───────────────────────────────────────────────────────────────────────────────────────────────────┼────────────┼─────────────────┼─────────────────────────┼────────────────────────────────────────────────────────────────────────────────────┤
# │  33 │ 5e9ddcd7-9644-4f97-8a82-41f3a99132bd │ E.H.F.S │ MACHINE LEARNING                                                                                  │ 2022-09-21 │               3 │ OCEAN                   │ https://drive.google.com/file/d/13Pmsz53dphEA2k9EprsARs6Jrm3v_e5K/view?usp=sharing │
# ├─────┼──────────────────────────────────────┼─────────┼───────────────────────────────────────────────────────────────────────────────────────────────────┼────────────┼─────────────────┼─────────────────────────┼────────────────────────────────────────────────────────────────────────────────────┤
# │  34 │ 7e0fae6f-7174-490a-844f-0ffe547d7565 │ E.H.F.S │ [JORNADA ANDROID] ANDROID: INTRODUÇÃO                                                             │ 2022-10-11 │               3 │ DIO                     │ https://drive.google.com/file/d/1itl5NdQvB9X0EmiIQNlEgDAvQD0XfrV7/view?usp=sharing │
# ├─────┼──────────────────────────────────────┼─────────┼───────────────────────────────────────────────────────────────────────────────────────────────────┼────────────┼─────────────────┼─────────────────────────┼────────────────────────────────────────────────────────────────────────────────────┤
# │  35 │ f1bfa257-670a-4be4-bf0d-54b84c7d22ca │ E.H.F.S │ [JORNADA ANDROID] ANDROID: LISTAS COM RECYCLERVIEW E MULTITHREAD                                  │ 2022-10-18 │               3 │ OCEAN                   │ https://drive.google.com/file/d/1tWyY7EwzIJnD-GK2lRM6cb5PGnuNFQBJ/view?usp=sharing │
# ├─────┼──────────────────────────────────────┼─────────┼───────────────────────────────────────────────────────────────────────────────────────────────────┼────────────┼─────────────────┼─────────────────────────┼────────────────────────────────────────────────────────────────────────────────────┤
# │  36 │ 15f04032-2967-47d2-9db1-4ccf394e4ef0 │ E.H.F.S │ [JORNADA ANDROID] ANDROID: WEBSERVICES COM RETROFIT E IMAGENS COM GLIDE                           │ 2022-10-22 │               3 │ OCEAN                   │ https://drive.google.com/file/d/1I-0hHGZPOy-LMJUeuQmfH-pz3OfM5n4J/view?usp=sharing │
# ├─────┼──────────────────────────────────────┼─────────┼───────────────────────────────────────────────────────────────────────────────────────────────────┼────────────┼─────────────────┼─────────────────────────┼────────────────────────────────────────────────────────────────────────────────────┤
# │  37 │ bb9102d9-5c62-4874-8cc5-de96077d5549 │ E.H.F.S │ [JORNADA ANDROID] ANDROID: JETPACK E ARQUITETURA (PARTE 1)                                        │ 2022-10-25 │               3 │ DIO                     │ https://drive.google.com/file/d/1rZ1T3xEk1F29S5l7AoGr2jqvZZN9wCpR/view?usp=sharing │
# ├─────┼──────────────────────────────────────┼─────────┼───────────────────────────────────────────────────────────────────────────────────────────────────┼────────────┼─────────────────┼─────────────────────────┼────────────────────────────────────────────────────────────────────────────────────┤
# │  38 │ 61bf5103-a1ef-4a6d-9ef8-57114cab692e │ E.H.F.S │ [JORNADA ANDROID] ANDROID: JETPACK E ARQUITETURA (PARTE 2)                                        │ 2022-10-27 │               3 │ DIO                     │ https://drive.google.com/file/d/1uw7ZePuVk3yIDaOYW3wr87CGeKTXJJ-J/view?usp=sharing │
# ├─────┼──────────────────────────────────────┼─────────┼───────────────────────────────────────────────────────────────────────────────────────────────────┼────────────┼─────────────────┼─────────────────────────┼────────────────────────────────────────────────────────────────────────────────────┤
# │  39 │ 9c1176b4-a101-464b-bac4-1e9080e74b34 │ E.H.F.S │ FUNDAMENTOS DE TI: HARDWARE E SOFTWARE                                                            │ 2022-12-31 │               7 │ FUNDAÇÃO BRADESCO       │ https://drive.google.com/file/d/1VGtS0-c55VIyDHjEREIBsJoB1onefxCH/view?usp=sharing │
# ├─────┼──────────────────────────────────────┼─────────┼───────────────────────────────────────────────────────────────────────────────────────────────────┼────────────┼─────────────────┼─────────────────────────┼────────────────────────────────────────────────────────────────────────────────────┤
# │  40 │ eec5fd39-6a55-4491-967a-30ef793603e2 │ E.H.F.S │ INTRODUÇÃO A REDES DE COMPUTADORES                                                                │ 2023-01-10 │              15 │ FUNDAÇÃO BRADESCO       │ https://drive.google.com/file/d/1injQgOsZe6V-wXk-DHJdX3dvuBC0kswW/view?usp=sharing │
# ├─────┼──────────────────────────────────────┼─────────┼───────────────────────────────────────────────────────────────────────────────────────────────────┼────────────┼─────────────────┼─────────────────────────┼────────────────────────────────────────────────────────────────────────────────────┤
# │  41 │ 5875e688-b5d4-439e-b97a-bb6436ccc7cb │ E.H.F.S │ CONHEÇA AS OPORTUNIDADES DA DIO                                                                   │ 2023-01-30 │               1 │ DIO                     │ https://drive.google.com/file/d/1JbESLKYM7coMCn6P4ooeR2784dyERaOR/view?usp=sharing │
# ├─────┼──────────────────────────────────────┼─────────┼───────────────────────────────────────────────────────────────────────────────────────────────────┼────────────┼─────────────────┼─────────────────────────┼────────────────────────────────────────────────────────────────────────────────────┤
# │  42 │ f2f91d71-23b9-451c-a234-20163d5e84ca │ E.H.F.S │ SEJA PROTAGONISTA NESTE BOOTCAMP                                                                  │ 2023-01-30 │               1 │ DIO                     │ https://drive.google.com/file/d/1rMxzHvJrGdZPk9QQN5Zi3zs5w0NYYE8i/view?usp=sharing │
# ├─────┼──────────────────────────────────────┼─────────┼───────────────────────────────────────────────────────────────────────────────────────────────────┼────────────┼─────────────────┼─────────────────────────┼────────────────────────────────────────────────────────────────────────────────────┤
# │  43 │ 064ab05d-6766-4b20-9cda-ef0428fa5946 │ E.H.F.S │ INTRODUÇÃO AO DESENVOLVIMENTO MODERNO DE SOFTWARE                                                 │ 2023-01-30 │               2 │ DIO                     │ https://drive.google.com/file/d/1fDcHyIHvnw7OZwHr6ZW5AA3nUtr42Lr2/view?usp=sharing │
# ├─────┼──────────────────────────────────────┼─────────┼───────────────────────────────────────────────────────────────────────────────────────────────────┼────────────┼─────────────────┼─────────────────────────┼────────────────────────────────────────────────────────────────────────────────────┤
# │  44 │ 54cb600f-101d-4842-8397-53c86373d31e │ E.H.F.S │ TRABALHANDO EM EQUIPES ÁGEIS                                                                      │ 2023-02-01 │               3 │ DIO                     │ https://drive.google.com/file/d/1iYTaSX_sOcFcf1wBIzdK4UWW5ql5Up3s/view?usp=sharing │
# ├─────┼──────────────────────────────────────┼─────────┼───────────────────────────────────────────────────────────────────────────────────────────────────┼────────────┼─────────────────┼─────────────────────────┼────────────────────────────────────────────────────────────────────────────────────┤
# │  45 │ 743ef342-a95c-44aa-990a-4378533fa690 │ E.H.F.S │ EXAME: FUNDAMENTOS DE INFORMÁTICA                                                                 │ 2023-02-01 │               1 │ IBSEC                   │ https://drive.google.com/file/d/1Rc_Gxd9ssclW9Uql4sfbLutxlC_ZKVd7/view?usp=sharing │
# ├─────┼──────────────────────────────────────┼─────────┼───────────────────────────────────────────────────────────────────────────────────────────────────┼────────────┼─────────────────┼─────────────────────────┼────────────────────────────────────────────────────────────────────────────────────┤
# │  46 │ f27f7a27-949e-41ec-9f7d-62c9a9601e10 │ E.H.F.S │ EXAME: FUNDAMENTOS DE REDE                                                                        │ 2023-02-01 │               1 │ IBSEC                   │ https://drive.google.com/file/d/1WX8ACLe-U-GizaVAOpkPfjzhJKZmQDgF/view?usp=sharing │
# ├─────┼──────────────────────────────────────┼─────────┼───────────────────────────────────────────────────────────────────────────────────────────────────┼────────────┼─────────────────┼─────────────────────────┼────────────────────────────────────────────────────────────────────────────────────┤
# │  47 │ 97199829-3db2-4d9d-a73c-b37b27f459a2 │ E.H.F.S │ LINUX FUNDAMENTOS                                                                                 │ 2023-02-01 │              40 │ FIAP                    │ https://drive.google.com/file/d/1ceWg-G8kqQfz46a8Ea1u8rW1RJqRc6Xr/view?usp=sharing │
# ├─────┼──────────────────────────────────────┼─────────┼───────────────────────────────────────────────────────────────────────────────────────────────────┼────────────┼─────────────────┼─────────────────────────┼────────────────────────────────────────────────────────────────────────────────────┤
# │  48 │ bfd9481a-77c8-40e9-b6d5-0fbc433cc10d │ E.H.F.S │ LINGUAGEM DE  PROGRAMAÇÃO PYTHON – BÁSICO                                                         │ 2023-02-06 │              18 │ FUNDAÇÃO BRADESCO       │ https://drive.google.com/file/d/1fn5hg58m2_DXe1N-MPeJ0-2g0MRLG3At/view?usp=sharing │
# ├─────┼──────────────────────────────────────┼─────────┼───────────────────────────────────────────────────────────────────────────────────────────────────┼────────────┼─────────────────┼─────────────────────────┼────────────────────────────────────────────────────────────────────────────────────┤
# │  49 │ 27f14dcc-2bf6-450e-9e50-98f0c4643497 │ E.H.F.S │ INTRODUÇÃO À PROGRAMAÇÃO E PENSAMENTO COMPUTACIONAL                                               │ 2023-02-10 │               5 │ DIO                     │ https://drive.google.com/file/d/1HKLPa_vAuz_4Xdel9pdVVrd7Bthbrx81/view?usp=sharing │
# ├─────┼──────────────────────────────────────┼─────────┼───────────────────────────────────────────────────────────────────────────────────────────────────┼────────────┼─────────────────┼─────────────────────────┼────────────────────────────────────────────────────────────────────────────────────┤
# │  50 │ 402eb0cb-01bd-417f-a130-7f3aa34b46c7 │ E.H.F.S │ INTRODUÇÃO AO SISTEMA                                                                             │ 2023-02-14 │               1 │ DIO                     │ https://drive.google.com/file/d/1MoGFuwang0UUa0Ecq3a_o0lt9yCEJi0C/view?usp=sharing │
# ├─────┼──────────────────────────────────────┼─────────┼───────────────────────────────────────────────────────────────────────────────────────────────────┼────────────┼─────────────────┼─────────────────────────┼────────────────────────────────────────────────────────────────────────────────────┤
# │  51 │ e678b8e3-dd76-4398-97a1-ad42a1e9b5b4 │ E.H.F.S │ INSTALANDO O LINUX                                                                                │ 2023-02-17 │               1 │ DIO                     │ https://drive.google.com/file/d/1rNtojMATGd2tts5ShUdF54HgzWw5FtX9/view?usp=sharing │
# ├─────┼──────────────────────────────────────┼─────────┼───────────────────────────────────────────────────────────────────────────────────────────────────┼────────────┼─────────────────┼─────────────────────────┼────────────────────────────────────────────────────────────────────────────────────┤
# │  52 │ 0446ff37-e8cc-4dc2-983e-b469334c1deb │ E.H.F.S │ ACESSO REMOTO A MÁQUINAS LINUX                                                                    │ 2023-02-17 │               1 │ DIO                     │ https://drive.google.com/file/d/1-XdnfyLpfHdLHU7UsuiOK9JgeaX220dt/view?usp=sharing │
# ├─────┼──────────────────────────────────────┼─────────┼───────────────────────────────────────────────────────────────────────────────────────────────────┼────────────┼─────────────────┼─────────────────────────┼────────────────────────────────────────────────────────────────────────────────────┤
# │  53 │ 570c1182-59cb-4254-8c85-5dbf86cf49fa │ E.H.F.S │ MANIPULANDO ARQUIVOS NO LINUX                                                                     │ 2023-02-18 │               3 │ DIO                     │ https://drive.google.com/file/d/17V0BFqZfupcNrPhP8-FCp4xQsvkOXYMp/view?usp=sharing │
# ├─────┼──────────────────────────────────────┼─────────┼───────────────────────────────────────────────────────────────────────────────────────────────────┼────────────┼─────────────────┼─────────────────────────┼────────────────────────────────────────────────────────────────────────────────────┤
# │  54 │ 1866e451-47ce-4627-ac4e-f25fb97fcb94 │ E.H.F.S │ GERENCIANDO USUÁRIOS NO LINUX                                                                     │ 2023-02-19 │               2 │ DIO                     │ https://drive.google.com/file/d/1ZgGr5mCDWXDnzkCXMGWS8Q6NW_v17lAt/view?usp=sharing │
# ├─────┼──────────────────────────────────────┼─────────┼───────────────────────────────────────────────────────────────────────────────────────────────────┼────────────┼─────────────────┼─────────────────────────┼────────────────────────────────────────────────────────────────────────────────────┤
# │  55 │ 55f2bebc-cda4-44e9-a06f-1c479058313d │ E.H.F.S │ LINUX DO ZERO | AULA INAUGURAL                                                                    │ 2023-02-23 │               2 │ DIO                     │ https://drive.google.com/file/d/1wEiTqz9gZte2UK1WgtwMdx8e7-AVXE2X/view?usp=sharing │
# ├─────┼──────────────────────────────────────┼─────────┼───────────────────────────────────────────────────────────────────────────────────────────────────┼────────────┼─────────────────┼─────────────────────────┼────────────────────────────────────────────────────────────────────────────────────┤
# │  56 │ 830f4ccf-65ac-4c3d-981a-8ba4e2f797b0 │ E.H.F.S │ COPIANDO ARQUIVOS E MANIPULANDO PROCESSOS                                                         │ 2023-02-23 │               1 │ DIO                     │ https://drive.google.com/file/d/1juWoGPMBf1aqb8co1J_G31-xoCowAB8g/view?usp=sharing │
# ├─────┼──────────────────────────────────────┼─────────┼───────────────────────────────────────────────────────────────────────────────────────────────────┼────────────┼─────────────────┼─────────────────────────┼────────────────────────────────────────────────────────────────────────────────────┤
# │  57 │ 5b334e95-9faf-4934-a447-27c76dd7e881 │ E.H.F.S │ GERENCIAMENTO DE DISCOS LINUX                                                                     │ 2023-02-23 │               1 │ DIO                     │ https://drive.google.com/file/d/1w_f2bSG8a2NG5ZZnTT61c8Q6tp78ilX5/view?usp=sharing │
# ├─────┼──────────────────────────────────────┼─────────┼───────────────────────────────────────────────────────────────────────────────────────────────────┼────────────┼─────────────────┼─────────────────────────┼────────────────────────────────────────────────────────────────────────────────────┤
# │  58 │ b6e785af-c640-4803-8d53-dcd615708a21 │ E.H.F.S │ INFRAESTRUTURA COMO CÓDIGO: SCRIPT DE CRIAÇÃO DE ESTRUTURA DE USUÁRIOS, DIRETÓRIOS E PERMISSÕES   │ 2023-02-23 │               1 │ DIO                     │ https://drive.google.com/file/d/11Uw701oEKle3gD1GYKZ9VpMdENzHD3Qa/view?usp=sharing │
# ├─────┼──────────────────────────────────────┼─────────┼───────────────────────────────────────────────────────────────────────────────────────────────────┼────────────┼─────────────────┼─────────────────────────┼────────────────────────────────────────────────────────────────────────────────────┤
# │  59 │ 39cbfde5-29c5-41ad-bfbb-1ffd48054fe2 │ E.H.F.S │ GERENCIAMENTO DE PACOTES LINUX                                                                    │ 2023-02-23 │               1 │ DIO                     │ https://drive.google.com/file/d/1JusZ2EyRnna4ELL2I7rq0La7AMuWdj0S/view?usp=sharing │
# ├─────┼──────────────────────────────────────┼─────────┼───────────────────────────────────────────────────────────────────────────────────────────────────┼────────────┼─────────────────┼─────────────────────────┼────────────────────────────────────────────────────────────────────────────────────┤
# │  60 │ 1c82e902-c73b-4452-bc08-5ebec5bc3cf2 │ E.H.F.S │ PYTHON                                                                                            │ 2023-02-24 │              80 │ FIAP                    │ https://drive.google.com/file/d/12GEENwg3c4I-eFA41nTDQBMoLoM962kg/view?usp=sharing │
# ├─────┼──────────────────────────────────────┼─────────┼───────────────────────────────────────────────────────────────────────────────────────────────────┼────────────┼─────────────────┼─────────────────────────┼────────────────────────────────────────────────────────────────────────────────────┤
# │  61 │ a647243a-2b42-49b4-baed-aa947b685eda │ E.H.F.S │ CRIANDO UM SERVIDOR WEB COM LINUX                                                                 │ 2023-02-24 │               1 │ DIO                     │ https://drive.google.com/file/d/17tdsfCI7esR5QuHB3ylGcbpFSvRMElmW/view?usp=sharing │
# ├─────┼──────────────────────────────────────┼─────────┼───────────────────────────────────────────────────────────────────────────────────────────────────┼────────────┼─────────────────┼─────────────────────────┼────────────────────────────────────────────────────────────────────────────────────┤
# │  62 │ 399ccd70-3979-4990-b596-dd5a8fbc844c │ E.H.F.S │ SERVIDOR DE BANCO DE DADOS COM LINUX                                                              │ 2023-02-24 │               1 │ DIO                     │ https://drive.google.com/file/d/1n671M3zS1sTwklx1TZEtH_IUOg65rznP/view?usp=sharing │
# ├─────┼──────────────────────────────────────┼─────────┼───────────────────────────────────────────────────────────────────────────────────────────────────┼────────────┼─────────────────┼─────────────────────────┼────────────────────────────────────────────────────────────────────────────────────┤
# │  63 │ e2fc30ee-01b4-4510-b79a-f5d0a4a9f962 │ E.H.F.S │ SERVIDORES DE ARQUIVOS COM LINUX                                                                  │ 2023-02-24 │               1 │ DIO                     │ https://drive.google.com/file/d/1WS364BGQthBSWbxKbDjBh1CgbE6gQYhx/view?usp=sharing │
# ├─────┼──────────────────────────────────────┼─────────┼───────────────────────────────────────────────────────────────────────────────────────────────────┼────────────┼─────────────────┼─────────────────────────┼────────────────────────────────────────────────────────────────────────────────────┤
# │  64 │ 3c1b3044-cd96-4dff-a433-0b0ba4bd6040 │ E.H.F.S │ DEVOPS: TUDO O QUE VOCÊ PRECISA SABER                                                             │ 2023-02-25 │               2 │ DIO                     │ https://drive.google.com/file/d/17wktOmrtoEHjg952j7-kidP0OMHAoQet/view?usp=sharing │
# ├─────┼──────────────────────────────────────┼─────────┼───────────────────────────────────────────────────────────────────────────────────────────────────┼────────────┼─────────────────┼─────────────────────────┼────────────────────────────────────────────────────────────────────────────────────┤
# │  65 │ d00e9337-6eb6-49a7-ad4a-2a5bb64b080d │ E.H.F.S │ DOCKER: UTILIZAÇÃO PRÁTICA NO CENÁRIO DE MICROSSERVIÇOS                                           │ 2023-02-25 │               2 │ DIO                     │ https://drive.google.com/file/d/1bNTrFKznTb2TJNppfml26m6xFp1hBe3b/view?usp=sharing │
# ├─────┼──────────────────────────────────────┼─────────┼───────────────────────────────────────────────────────────────────────────────────────────────────┼────────────┼─────────────────┼─────────────────────────┼────────────────────────────────────────────────────────────────────────────────────┤
# │  66 │ 2e90b634-3ee8-4bf8-8274-f871229ce0e5 │ E.H.F.S │ LINUX DO ZERO                                                                                     │ 2023-02-25 │              44 │ DIO                     │ https://drive.google.com/file/d/1c5H3OkAyqkIfJi9V55f02tzLHDM0RHYU/view?usp=sharing │
# ├─────┼──────────────────────────────────────┼─────────┼───────────────────────────────────────────────────────────────────────────────────────────────────┼────────────┼─────────────────┼─────────────────────────┼────────────────────────────────────────────────────────────────────────────────────┤
# │  67 │ 8643d0c3-819d-453d-a0a1-34749e931845 │ E.H.F.S │ CONFIGURANDO SERVIDORES LINUX E INTRODUÇÃO AO DOCKER                                              │ 2023-02-25 │               8 │ DIO                     │ https://drive.google.com/file/d/13ojDqUt13YpkAIMeQQMRqGVmgfF58qP8/view?usp=sharing │
# ├─────┼──────────────────────────────────────┼─────────┼───────────────────────────────────────────────────────────────────────────────────────────────────┼────────────┼─────────────────┼─────────────────────────┼────────────────────────────────────────────────────────────────────────────────────┤
# │  68 │ 6fe7fd7a-2498-487a-82ed-0f02d42c2bc0 │ E.H.F.S │ DOCKER: UTILIZAÇÃO PRÁTICA NO CENÁRIO DE MICROSSERVIÇOS                                           │ 2023-02-25 │               2 │ DIO                     │ https://drive.google.com/file/d/1pFP0nTlSDXMEHfJ-JV8wAp61C-doPFx3/view?usp=sharing │
# ├─────┼──────────────────────────────────────┼─────────┼───────────────────────────────────────────────────────────────────────────────────────────────────┼────────────┼─────────────────┼─────────────────────────┼────────────────────────────────────────────────────────────────────────────────────┤
# │  69 │ edac8819-f326-43a8-8a39-0d0b2bbaecaa │ E.H.F.S │ DESENVOLVEDOR FRONT-END                                                                           │ 2023-03-07 │             276 │ SOFTEX                  │ https://drive.google.com/file/d/1LVqK02E46RDkJ9VUrT0rG8i98Fo3lpkN/view?usp=sharing │
# ├─────┼──────────────────────────────────────┼─────────┼───────────────────────────────────────────────────────────────────────────────────────────────────┼────────────┼─────────────────┼─────────────────────────┼────────────────────────────────────────────────────────────────────────────────────┤
# │  70 │ a751d1a6-df57-493e-a2c1-bd2aa2966e31 │ E.H.F.S │ BOOTCAMP CLOUD AWS | AULA INAUGURAL                                                               │ 2023-03-17 │               1 │ DIO                     │ https://drive.google.com/file/d/1QyTt1rhRghQArru-Ma70_5cu2YABCyoi/view?usp=sharing │
# ├─────┼──────────────────────────────────────┼─────────┼───────────────────────────────────────────────────────────────────────────────────────────────────┼────────────┼─────────────────┼─────────────────────────┼────────────────────────────────────────────────────────────────────────────────────┤
# │  71 │ c53b4ded-a41b-4720-8ecd-ec2f532bddfb │ E.H.F.S │ INTRODUÇÃO AO GIT E AO GITHUB                                                                     │ 2023-03-23 │               3 │ DIO                     │ https://drive.google.com/file/d/1jxCrTyF3HddFOpBNs9vam4RtP4RoRNYG/view?usp=sharing │
# ├─────┼──────────────────────────────────────┼─────────┼───────────────────────────────────────────────────────────────────────────────────────────────────┼────────────┼─────────────────┼─────────────────────────┼────────────────────────────────────────────────────────────────────────────────────┤
# │  72 │ bffacef5-7ce2-48fd-bd53-9fc5f638f9f7 │ E.H.F.S │ CONHEÇA TUDO SOBRE A LGPD: PRIMEIRAS NOÇÕES                                                       │ 2023-03-24 │               2 │ DIO                     │ https://drive.google.com/file/d/1Lmx7IpEn5Vh-uolyp9lj3InAqtQj3fG3/view?usp=sharing │
# ├─────┼──────────────────────────────────────┼─────────┼───────────────────────────────────────────────────────────────────────────────────────────────────┼────────────┼─────────────────┼─────────────────────────┼────────────────────────────────────────────────────────────────────────────────────┤
# │  73 │ 16198103-8963-44a1-872d-57c2c355e4ef │ E.H.F.S │ COMPUTAÇÃO EM AWS                                                                                 │ 2023-03-26 │               1 │ DIO                     │ https://drive.google.com/file/d/15SCTF35aJihyxcEvJ2sVCto26MNXGKHv/view?usp=sharing │
# ├─────┼──────────────────────────────────────┼─────────┼───────────────────────────────────────────────────────────────────────────────────────────────────┼────────────┼─────────────────┼─────────────────────────┼────────────────────────────────────────────────────────────────────────────────────┤
# │  74 │ daf21d10-587c-408b-94c5-0e5eb2d1bf88 │ E.H.F.S │ INTRODUÇÃO AO CONCEITO DE CLOUD                                                                   │ 2023-03-26 │               1 │ DIO                     │ https://drive.google.com/file/d/1w1af3nDgWbT7zwlmuOJZrmuw5LF0Tcjw/view?usp=sharing │
# ├─────┼──────────────────────────────────────┼─────────┼───────────────────────────────────────────────────────────────────────────────────────────────────┼────────────┼─────────────────┼─────────────────────────┼────────────────────────────────────────────────────────────────────────────────────┤
# │  75 │ 9bcd3cc3-cbad-4f57-a4cc-f3d6e5738508 │ E.H.F.S │ INTRODUÇÃO PRÁTICA A COMPUTAÇÃO EM NUVEM USANDO AWS                                               │ 2023-03-26 │               2 │ DIO                     │ https://drive.google.com/file/d/1iJzXjRVusHODKgdqX3Uk3smPPCz_jyv7/view?usp=sharing │
# ├─────┼──────────────────────────────────────┼─────────┼───────────────────────────────────────────────────────────────────────────────────────────────────┼────────────┼─────────────────┼─────────────────────────┼────────────────────────────────────────────────────────────────────────────────────┤
# │  76 │ 33053077-17cc-4206-b915-987ed8e18e50 │ E.H.F.S │ INFRAESTRUTURA GLOBAL AWS                                                                         │ 2023-03-26 │               1 │ DIO                     │ https://drive.google.com/file/d/1EfbAUqlGJwuC8Ybcn3fh-jHVKbWBhsxq/view?usp=sharing │
# ├─────┼──────────────────────────────────────┼─────────┼───────────────────────────────────────────────────────────────────────────────────────────────────┼────────────┼─────────────────┼─────────────────────────┼────────────────────────────────────────────────────────────────────────────────────┤
# │  77 │ 4e723138-92a3-4901-adce-71eb4b76adf3 │ E.H.F.S │ REDES EM AWS                                                                                      │ 2023-03-27 │               1 │ DIO                     │ https://drive.google.com/file/d/1ns2Nd6tg0WED7VGHgQNAwT7ugKy1wcWi/view?usp=sharing │
# ├─────┼──────────────────────────────────────┼─────────┼───────────────────────────────────────────────────────────────────────────────────────────────────┼────────────┼─────────────────┼─────────────────────────┼────────────────────────────────────────────────────────────────────────────────────┤
# │  78 │ 3d199082-bfbb-474c-822f-729cc0ac4df0 │ E.H.F.S │ ARMAZENAMENTO E BANCO DE DADOS AWS                                                                │ 2023-03-27 │               2 │ DIO                     │ https://drive.google.com/file/d/10S12_6H6WQLtsKemu2onCdoiyIRbzZj1/view?usp=sharing │
# ...
# ├─────┼──────────────────────────────────────┼─────────┼───────────────────────────────────────────────────────────────────────────────────────────────────┼────────────┼─────────────────┼─────────────────────────┼────────────────────────────────────────────────────────────────────────────────────┤
# │ 160 │ 2a384a34-f576-46a6-8eb7-3fb1d1862577 │ E.H.F.S │ ALGORITMOS DE SVM (SUPPORT VECTOR MACHINE)                                                        │ 2024-04-26 │               1 │ DIO                     │ https://drive.google.com/file/d/1H1BVvxhg_2trdcg4phlQD77_A62L_WdD/view?usp=sharing │
# ├─────┼──────────────────────────────────────┼─────────┼───────────────────────────────────────────────────────────────────────────────────────────────────┼────────────┼─────────────────┼─────────────────────────┼────────────────────────────────────────────────────────────────────────────────────┤
# │ 161 │ 56af7460-d9af-458c-9225-72cee30e17c2 │ E.H.F.S │ LINGUAGENS DE PROGRAMAÇÃO PARA MACHINE LEARNING                                                   │ 2024-04-26 │               1 │ DIO                     │ https://drive.google.com/file/d/1vKRKDzjKGJ_GIHlTMvYlqkR2xp81rl6m/view?usp=sharing │
# ├─────┼──────────────────────────────────────┼─────────┼───────────────────────────────────────────────────────────────────────────────────────────────────┼────────────┼─────────────────┼─────────────────────────┼────────────────────────────────────────────────────────────────────────────────────┤
# │ 162 │ d7e4ac7d-6692-46dc-a88f-3a23d29035f9 │ E.H.F.S │ CLASSIFICAÇÃO DE PROBLEMAS: EXPLORANDO DATASETS                                                   │ 2024-04-26 │               1 │ DIO                     │ https://drive.google.com/file/d/12KsJ2k3YEwG75j1Ry6uXWX_GTkED8bEi/view?usp=sharing │
# ├─────┼──────────────────────────────────────┼─────────┼───────────────────────────────────────────────────────────────────────────────────────────────────┼────────────┼─────────────────┼─────────────────────────┼────────────────────────────────────────────────────────────────────────────────────┤
# │ 163 │ d456238e-5e51-4b81-bf6f-3c6239d6bae8 │ E.H.F.S │ PREPARAR OS DADOS PARA EXPLORAÇÃO                                                                 │ 2024-05-01 │              22 │ COURSERA-GOOGLE         │ https://drive.google.com/file/d/1nR-7G7byRGwCXSGo8Ai_zj8JyPzLs8XI/view?usp=sharing │
# ├─────┼──────────────────────────────────────┼─────────┼───────────────────────────────────────────────────────────────────────────────────────────────────┼────────────┼─────────────────┼─────────────────────────┼────────────────────────────────────────────────────────────────────────────────────┤
# │ 164 │ c8e55967-9ea4-44c7-a990-95843c8a13c2 │ E.H.F.S │ INTRODUÇÃO À INTELIGÊNCIA ARTIFICIAL                                                              │ 2024-05-02 │               1 │ DIO                     │ https://drive.google.com/file/d/1ygl89OvZ64XjrmtiIorao3vbmqCrXo6F/view?usp=sharing │
# ├─────┼──────────────────────────────────────┼─────────┼───────────────────────────────────────────────────────────────────────────────────────────────────┼────────────┼─────────────────┼─────────────────────────┼────────────────────────────────────────────────────────────────────────────────────┤
# │ 165 │ 8512d0e6-e2e8-4434-a729-5135432735a1 │ E.H.F.S │ PROCESSAR OS DADOS PARA LIMPÁ-LOS                                                                 │ 2024-05-14 │              22 │ COURSERA-GOOGLE         │ https://drive.google.com/file/d/1NoshOWmQUa0Ja98_6yGbfA_EwWTmMTHB/view?usp=sharing │
# ├─────┼──────────────────────────────────────┼─────────┼───────────────────────────────────────────────────────────────────────────────────────────────────┼────────────┼─────────────────┼─────────────────────────┼────────────────────────────────────────────────────────────────────────────────────┤
# │ 166 │ 9a88787b-e6cb-46b6-9575-d6eaab422e4d │ E.H.F.S │ COMPARTILHAR OS DADOS COM A ARTE DA VISUALIZAÇÃO                                                  │ 2024-05-25 │              24 │ COURSERA-GOOGLE         │ https://drive.google.com/file/d/1Ee61X778Wcv4SoEv74uXANE0_2lrvfn-/view?usp=sharing │
# ├─────┼──────────────────────────────────────┼─────────┼───────────────────────────────────────────────────────────────────────────────────────────────────┼────────────┼─────────────────┼─────────────────────────┼────────────────────────────────────────────────────────────────────────────────────┤
# │ 167 │ 05409a1f-7d40-455e-8072-e87d3df46783 │ E.H.F.S │ ANALISAR OS DADOS PARA RESPONDER ÀS PERGUNTAS                                                     │ 2024-05-28 │              26 │ COURSERA-GOOGLE         │ https://drive.google.com/file/d/1xeE26g6pMY03_-zj-yLQQrpUVi0h3yr-/view?usp=sharing │
# ├─────┼──────────────────────────────────────┼─────────┼───────────────────────────────────────────────────────────────────────────────────────────────────┼────────────┼─────────────────┼─────────────────────────┼────────────────────────────────────────────────────────────────────────────────────┤
# │ 168 │ a1ebe48e-508a-4d9c-a345-a2c3540f29a6 │ E.H.F.S │ ANÁLISE DE DADOS COM PROGRAMAÇÃO EM R                                                             │ 2024-05-28 │              36 │ COURSERA-GOOGLE         │ https://drive.google.com/file/d/1gEzTFFZs3qIhatYrZoI_8tjMM3cnRjv-/view?usp=sharing │
# ├─────┼──────────────────────────────────────┼─────────┼───────────────────────────────────────────────────────────────────────────────────────────────────┼────────────┼─────────────────┼─────────────────────────┼────────────────────────────────────────────────────────────────────────────────────┤
# │ 169 │ 9115e959-5e10-402b-bfa1-8f100165074d │ E.H.F.S │ PROJETO FINAL DE DATA ANALYTICS DO GOOGLE: CONCLUA UM ESTUDO DE CASO                              │ 2024-05-28 │              10 │ COURSERA-GOOGLE         │ https://drive.google.com/file/d/1okHqrUGeHXYxNGGnsGnB0OvNNeoxG6Vo/view?usp=sharing │
# ├─────┼──────────────────────────────────────┼─────────┼───────────────────────────────────────────────────────────────────────────────────────────────────┼────────────┼─────────────────┼─────────────────────────┼────────────────────────────────────────────────────────────────────────────────────┤
# │ 170 │ 72678d8e-bb97-4a01-9517-2854a83c74d9 │ E.H.F.S │ CERTIFICADO PROFISSIONAL DE ANÁLISE DE  DADOS DO GOOGLE                                           │ 2024-05-28 │               1 │ COURSERA-GOOGLE         │ https://drive.google.com/file/d/1VVunQ_q2oLL19CMLAHbTr8Z7KOFbdWkf/view?usp=sharing │
# ├─────┼──────────────────────────────────────┼─────────┼───────────────────────────────────────────────────────────────────────────────────────────────────┼────────────┼─────────────────┼─────────────────────────┼────────────────────────────────────────────────────────────────────────────────────┤
# │ 171 │ a1a55d41-7b58-411a-8045-c44b3ce6871d │ E.H.F.S │ GOOGLE DATA ANALYTICS (PT) PELA GOOGLE NO COURSERA                                                │ 2024-05-28 │             178 │ COURSERA-GOOGLE         │ https://drive.google.com/file/d/1RGIXCCHV8Yw-fm8pT6Aash2G_t8poELw/view?usp=sharing │
# ├─────┼──────────────────────────────────────┼─────────┼───────────────────────────────────────────────────────────────────────────────────────────────────┼────────────┼─────────────────┼─────────────────────────┼────────────────────────────────────────────────────────────────────────────────────┤
# │ 172 │ c510bffc-b3ca-4b6c-adf3-df8252ba9d74 │ E.H.F.S │ FUNDAMENTOS DE BI: KPIS E MÉTRICAS                                                                │ 2024-06-04 │               1 │ DIO                     │ https://drive.google.com/file/d/1m0Y_XZo6eBMzyqIMe5G1jWiy3myU9YTM/view?usp=sharing │
# ├─────┼──────────────────────────────────────┼─────────┼───────────────────────────────────────────────────────────────────────────────────────────────────┼────────────┼─────────────────┼─────────────────────────┼────────────────────────────────────────────────────────────────────────────────────┤
# │ 173 │ 48031777-2445-4421-9186-47f6ffd861ce │ E.H.F.S │ CRIANDO DASHBOARD INTERATIVOS COM POWER BI                                                        │ 2024-06-04 │               2 │ DIO                     │ https://drive.google.com/file/d/1CslB2nbBVOUFec9lrnQKGU1Filp_J7CW/view?usp=sharing │
# ├─────┼──────────────────────────────────────┼─────────┼───────────────────────────────────────────────────────────────────────────────────────────────────┼────────────┼─────────────────┼─────────────────────────┼────────────────────────────────────────────────────────────────────────────────────┤
# │ 174 │ 5714603c-16cb-4cc8-ad76-4c60b66daea7 │ E.H.F.S │ CRIANDO DASHBOARD INTERATIVOS COM POWER BI                                                        │ 2024-06-04 │               2 │ DIO                     │ https://drive.google.com/file/d/1MyLzg4MFoE0yYV0rM_0_7-FXUdttCe4-/view?usp=sharing │
# ├─────┼──────────────────────────────────────┼─────────┼───────────────────────────────────────────────────────────────────────────────────────────────────┼────────────┼─────────────────┼─────────────────────────┼────────────────────────────────────────────────────────────────────────────────────┤
# │ 175 │ 5f224b11-fc29-4ddf-b467-df575893973a │ E.H.F.S │ TRABALHANDO COM VISUAIS NO POWER BI                                                               │ 2024-06-04 │               4 │ DIO                     │ https://drive.google.com/file/d/1D9nFpxcmWP6hhheDwnP0M6vL28R1fMi6/view?usp=sharing │
# ├─────┼──────────────────────────────────────┼─────────┼───────────────────────────────────────────────────────────────────────────────────────────────────┼────────────┼─────────────────┼─────────────────────────┼────────────────────────────────────────────────────────────────────────────────────┤
# │ 176 │ 5c7b6a30-2df0-4e0d-8731-84e1ba260287 │ E.H.F.S │ COLETA E EXTRAÇÃO DE DADOS COM POWER BI                                                           │ 2024-06-05 │               3 │ DIO                     │ https://drive.google.com/file/d/112hotxNgc71xGSoPNYskhgakje0Dh9al/view?usp=sharing │
# ├─────┼──────────────────────────────────────┼─────────┼───────────────────────────────────────────────────────────────────────────────────────────────────┼────────────┼─────────────────┼─────────────────────────┼────────────────────────────────────────────────────────────────────────────────────┤
# │ 177 │ b9d92510-a962-40c3-8d1d-3f7f45fc2d5f │ E.H.F.S │ LIMPEZA E TRANSFORMAÇÃO DE DADOS COM POWER BI                                                     │ 2024-06-05 │               2 │ DIO                     │ https://drive.google.com/file/d/18SPjkNhuHSwsMZw8THPhOen_-2GUXCru/view?usp=sharing │
# ├─────┼──────────────────────────────────────┼─────────┼───────────────────────────────────────────────────────────────────────────────────────────────────┼────────────┼─────────────────┼─────────────────────────┼────────────────────────────────────────────────────────────────────────────────────┤
# │ 178 │ eeba29fd-a03c-46d8-94c6-12a61dc9a27d │ E.H.F.S │ COLETA E EXTRAÇÃO DE DADOS COM POWER BI                                                           │ 2024-06-05 │               3 │ DIO                     │ https://drive.google.com/file/d/1NcpNrxsdL7AynFceR_Lz15wszrFgIIlf/view?usp=sharing │
# ├─────┼──────────────────────────────────────┼─────────┼───────────────────────────────────────────────────────────────────────────────────────────────────┼────────────┼─────────────────┼─────────────────────────┼────────────────────────────────────────────────────────────────────────────────────┤
# │ 179 │ 00b6c4ea-802a-4383-88a8-0ebaebb30774 │ E.H.F.S │ PYTHON DATA ANALYTICS                                                                             │ 2024-06-05 │              68 │ DIO                     │ https://drive.google.com/file/d/1Twjk99b1HnZpfC9x59TKsalmTirrCoJD/view?usp=sharing │
# ├─────┼──────────────────────────────────────┼─────────┼───────────────────────────────────────────────────────────────────────────────────────────────────┼────────────┼─────────────────┼─────────────────────────┼────────────────────────────────────────────────────────────────────────────────────┤
# │ 180 │ 8f46c471-1d4e-46e1-8b07-01ab96b388b1 │ E.H.F.S │ LIMPEZA E TRANSFORMAÇÃO DE DADOS COM POWER BI                                                     │ 2024-06-05 │               2 │ DIO                     │ https://drive.google.com/file/d/1GlYJc1hou_oO5kikY4h2D95AW0vIodmO/view?usp=sharing │
# ├─────┼──────────────────────────────────────┼─────────┼───────────────────────────────────────────────────────────────────────────────────────────────────┼────────────┼─────────────────┼─────────────────────────┼────────────────────────────────────────────────────────────────────────────────────┤
# │ 181 │ 16a93577-c135-42d8-b399-b53358a2afda │ E.H.F.S │ INTELIGÊNCIA ARTIFICIAL APLICADA À VISÃO COMPUTACIONAL                                            │ 2024-06-30 │             240 │ FACTI                   │ https://drive.google.com/file/d/1VJ2KLDvv5ctc_Ib2gJFxEDKttnG5Jal3/view?usp=sharing │
# ├─────┼──────────────────────────────────────┼─────────┼───────────────────────────────────────────────────────────────────────────────────────────────────┼────────────┼─────────────────┼─────────────────────────┼────────────────────────────────────────────────────────────────────────────────────┤
# │ 182 │ 198f1c02-2f6f-436c-9c71-9703bc011c6e │ E.H.F.S │ SQL COM PYHTHON (PART 01)                                                                         │ 2024-07-16 │               3 │ DIO                     │ https://drive.google.com/file/d/1111msxNyGG7OLOOux7HaaZlnHlq3PBOq/view?usp=sharing │
# ├─────┼──────────────────────────────────────┼─────────┼───────────────────────────────────────────────────────────────────────────────────────────────────┼────────────┼─────────────────┼─────────────────────────┼────────────────────────────────────────────────────────────────────────────────────┤
# │ 183 │ 7b6558b4-6f0a-4ea8-a5b1-2fb7398a5870 │ E.H.F.S │ DEEP LEARNING: INTRODUÇÃO COM KERAS  E PYTHON                                                     │ 2024-07-18 │               4 │ OCEAN                   │ https://drive.google.com/file/d/13XSWIJVgjlRxb80v4CcgwdF8nrDOx23o/view?usp=sharing │
# ├─────┼──────────────────────────────────────┼─────────┼───────────────────────────────────────────────────────────────────────────────────────────────────┼────────────┼─────────────────┼─────────────────────────┼────────────────────────────────────────────────────────────────────────────────────┤
# │ 184 │ ea4ceef6-e79b-48ef-bdfb-3901349ce06d │ E.H.F.S │ FUNDAMENTOS DE IA PARA DEVS                                                                       │ 2024-07-22 │              42 │ DIO-SANTANDER           │ https://drive.google.com/file/d/144DmYdIpre9QqqSpQ9ELjpjj5hZXUvVZ/view?usp=sharing │
# ├─────┼──────────────────────────────────────┼─────────┼───────────────────────────────────────────────────────────────────────────────────────────────────┼────────────┼─────────────────┼─────────────────────────┼────────────────────────────────────────────────────────────────────────────────────┤
# │ 185 │ b8bf1063-6fcf-49c5-aa9e-eaa2257c9eb4 │ E.H.F.S │ FUNDAMENTOS: DADOS, DADOS, EM TODOS OS LUGARES                                                    │ 2024-08-06 │              19 │ COURSERA-GOOGLE         │ https://drive.google.com/file/d/186F9if_70-w0JG_Qo1KzguEZ781MQPrX/view?usp=sharing │
# ╘═════╧══════════════════════════════════════╧═════════╧═══════════════════════════════════════════════════════════════════════════════════════════════════╧════════════╧═════════════════╧═════════════════════════╧════════════════════════════════════════════════════════════════════════════════════╛
#
# Menu de Opções
# 1. Adicionar Certificado
# 2. Visualizar Todos os Certificados
# 3. Sair
